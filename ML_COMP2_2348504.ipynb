# %% [markdown]
# <a href="https://colab.research.google.com/github/anushChrist/ML_LAB/blob/main/ML_COMP2_2348504.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import chi2_contingency

# %% [markdown]
# Loading Data

# %%
df = pd.read_csv('/content/2015.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Looking for missing values

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df['Happiness Score'].describe()
# Out:
# count    158.000000
# mean       5.375734
# std        1.145010
# min        2.839000
# 25%        4.526000
# 50%        5.232500
# 75%        6.243750
# max        7.587000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Binning Happiness Score into Low, Medium, High

# %%
happiness_group = ['low', 'medium', 'high']
df['happiness_group'] = ''
for x in df.index:
  if df.loc[x, 'Happiness Score'] > 6:
    df.loc[x, 'happiness_group'] = 'high'
  elif df.loc[x, 'Happiness Score'] > 3:
    df.loc[x, 'happiness_group'] = 'medium'
  else:
    df.loc[x, 'happiness_group'] = 'low'

# %% [markdown]
# Chi-Square Test

# %%
contingency_table = pd.crosstab(df['Region'], df['Happiness Rank'])
chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)
p_val
# Out:
# 0.4107040079831256

# %% [markdown]
# One Hot Encoding

# %%
df = pd.get_dummies(df, columns = ['Region'])
df
# Out:
#          Country  Happiness Rank  Happiness Score  Standard Error  \
# 0    Switzerland               1            7.587         0.03411
# 1        Iceland               2            7.561         0.04884
# 2        Denmark               3            7.527         0.03328
# 3         Norway               4            7.522         0.03880
# 4         Canada               5            7.427         0.03553
# ..           ...             ...              ...             ...
# 153       Rwanda             154            3.465         0.03464
# 154        Benin             155            3.340         0.03656
# 155        Syria             156            3.006         0.05015
# 156      Burundi             157            2.905         0.08658
# 157         Togo             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# Normalization

# %%
scaler = MinMaxScaler()
df['Economy (GDP per Capita)'] = scaler.fit_transform(df['Economy (GDP per Capita)'].values.reshape(-1,1))
df['Economy (GDP per Capita)']
# Out:
# 0      0.826132
# 1      0.770412
# 2      0.784113
# 3      0.863099
# 4      0.784592
#          ...
# 153    0.131376
# 154    0.169573
# 155    0.392329
# 156    0.009051
# 157    0.123449
# Name: Economy (GDP per Capita), Length: 158, dtype: float64

# %%
df.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'happiness_group',
#        'Region_Australia and New Zealand', 'Region_Central and Eastern Europe',
#        'Region_Eastern Asia', 'Region_Latin America and Caribbean',
#        'Region_Middle East and Northern Africa', 'Region_North America',
#        'Region_Southeastern Asia', 'Region_Southern Asia',
#        'Region_Sub-Saharan Africa', 'Region_Western Europe'],
#       dtype='object')

# %% [markdown]
# Covariance Matrix

# %%
numerical = ['Happiness Score', 'Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']
corr_matrix = df[numerical].corr()
corr_matrix
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %% [markdown]
# Visualization

# %%
count = {'high': 0, 'medium': 0, 'low': 0}
for x in df.index:
    if df.loc[x, 'happiness_group'] == 'high':
         count['high'] += 1
    elif df.loc[x, 'happiness_group'] == 'medium':
        count['medium'] += 1
    elif df.loc[x, 'happiness_group'] == 'low':
        count['low'] += 1
count
# Out:
# {'high': 44, 'medium': 112, 'low': 2}

# %%
df['Health (Life Expectancy)'] = scaler.fit_transform(df['Health (Life Expectancy)'].values.reshape(-1,1))
df['Health (Life Expectancy)'].plot(kind = 'hist')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
